# %% [markdown]
# ### Your Name Here: Carter
# ### Your TF Name: Joe
# ### Graduate or Undergraduate Credit: Graduate

# %% [markdown]
# ## This is e29 PSET2
# ##### 20180215_e29_pset2
# ##### Harvard University DCE CSCI-E29
# ##### Instructor: Nenad Svrzikapa
# ##### Staff: Joe Palin, Kaleigh Douglas, Lena Hajjar, Phil Lodine, Alan Xie
# ### Instructions:
#
# PSET2 is designed to advance your data exploration and manipulation skills with the Pandas library.  Before you get started please review and understand our Academic Integrity policy.  We understand that for some of your work you may have to use external sorces.  Please cite and be a good acedemic citizen. Remember that All homework assignments, quizzes and exams must be your independent work!
#
# Tips from staff:
#
# 1. Don't wait until the last day, our Psets require time and learning
# 2. Piazza is there for you, we are a team and our goal is not to test you, we want to teach you! Please ask questions!
# 3. Program a bit every day.  You can't learn these concepts by reading 2 chapters and attempting to solve the problems. Read a little, try the code, change the code,break the code, understand, learn.
#
# ##### Note: All Datasets required for this pset are available on Canvas

# %% [markdown]
# ## Problem 1:
# ### Created by: Lena
# ### Undergraduate 2.5 points Graduate 2 points

# %% [markdown]
# # Exploring Pandas at Wal-Mart*
#
# We're going to explore some features of Pandas using at this dataset of Wal-Mart stores that opened since 1962.
#
# #### *You can't find actual pandas at Wal-Mart.

# %% [markdown]
# ### Information about the dataset
# You can find the data in the file walmart.csv (source: https://github.com/plotly/datasets) The file has over 2000 records of Wal-Marts and Supercenters that have opened in the US since 1962. The dataset has the following columns:
# <ul>
# <li><b>storenum:</b> The store number</li>
# <li><b>OPENDATE:</b> The opening date of the store in MM/DD/YYYY format</li>
# <li><b>date_super:</b> The date that the store was converted into a supercenter in MM/DD/YYYY format. There may be empty values if the store was not converted into a supercenter</li>
# <li><b>conversion:</b> The number of conversions from Wal-Mart to Supercenter that the store has gone through. </li>
# <li><b>STREETADDR:</b> The store's street address</li>
# <li><b>STRCITY:</b> The store's city</li>
# <li><b>STRSTATE:</b> The store's state</li>
# <li><b>ZIPCODE:</b> The store's zipcode</li>
# <li><b>type_store:</b> The type of store. Possible values are Wal-mart and SuperCenter</li>
# <li><b>LAT:</b> The store's latitude</li>
# <li><b>LON:</b> The store's longitude</li>
# <li><b>MONTH:</b> The month the store opened</li>
# <li><b>DAY:</b> The day the store opened</li>
# <li><b>YEAR:</b> The year the store opened</li>
# </ul>

# %% [markdown]
# ### Part 1: Getting the data
# You should have downloaded walmart.csv from the assignment. Now we need to load it into a dataframe.

# %%
import numpy as np
import pandas as pd
### Part 2: Exploring the dataimport pandas as pd

# load walmart.csv into a dataframe. Hint: use the read_csv function
walmart = pd.read_csv("walmart.csv")

# %% [markdown]
# ### Part 2: Exploring the data

# %% [markdown]
# Let's take a look at what this data looks like. Display the first 10 rows of this dataset using Data slicing.

# %%
# display first 10 rows of the walmart dataframe
tenRows = walmart.iloc[0:10, :]
tenRows
# Out:
#    storenum OPENDATE date_super  conversion  st  county  \
# 0         1   7/1/62     3/1/97         1.0   5       7
# 1         2   8/1/64     3/1/96         1.0   5       9
# 2         4   8/1/65     3/1/02         1.0   5       7
# 3         8  10/1/67     3/1/93         1.0   5      29
# 4         7  10/1/67        NaN         NaN   5     119
# 5        10   7/1/68     3/1/98         1.0  40      21
# 6        13  11/1/68     3/1/96         1.0  29      97
# 7        12   7/1/68     3/1/94         1.0  40     131
# 8        11   3/1/68    2/20/02         1.0   5       5
# 9         9   3/1/68     3/1/00         1.0  29     143
#
#                STREETADDR            STRCITY STRSTATE  ZIPCODE   type_store  \
# 0        2110 WEST WALNUT             Rogers       AR    72756  Supercenter
# 1        1417 HWY 62/65 N           Harrison       AR    72601  Supercenter
# 2       2901 HWY 412 EAST     Siloam Springs       AR    72761  Supercenter
# 3   1621 NORTH BUSINESS 9          Morrilton       AR    72110  Supercenter
# 4  3801 CAMP ROBINSON RD.  North Little Rock       AR    72118     Wal-Mart
# 5     2020 SOUTH MUSKOGEE          Tahlequah       OK    74464  Supercenter
# 6          2705 GRAND AVE           Carthage       MO    64836  Supercenter
# 7    1500 LYNN RIGGS BLVD          Claremore       OK    74017  Supercenter
# 8       65 WAL-MART DRIVE      Mountain Home       AR    72653  Supercenter
# 9         1303 SOUTH MAIN           Sikeston       MO    63801  Supercenter
#
#          LAT       LON  MONTH  DAY  YEAR
# 0  36.342235 -94.07141      7    1  1962
# 1  36.236984 -93.09345      8    1  1964
# 2  36.179905 -94.50208      8    1  1965
# 3  35.156491 -92.75858     10    1  1967
# 4  34.813269 -92.30229     10    1  1967
# 5  35.923658 -94.97185      7    1  1968
# 6  37.168985 -94.31164     11    1  1968
# 7  36.327143 -95.61192      7    1  1968
# 8  36.329026 -92.35781      3    1  1968
# 9  36.891163 -89.58355      3    1  1968

# %% [markdown]
# You can find a lot of information about a pandas dataframe. In the cell below, find the number of rows and columns that are in this dataset. <br><b>HINT:</b> Remember that NumPy is the foundation of Pandas, how would you find the number of rows and columns in a NumPy array?

# %%
# put your code here
# https://stackoverflow.com/questions/15943769/how-do-i-get-the-row-count-of-a-pandas-dataframe/38025280

#number of rows
walRow = walmart.shape[0]
print("This dataset has", walRow, "rows.")

#number of columns
walCol = walmart.shape[1]
print("This dataset has", walCol, "columns.")
# Out:
# This dataset has 2992 rows.
# This dataset has 16 columns.

# %% [markdown]
# You can also display one or more columns of your choice. Display the type_store column.

# %%
#your code here 
type_store = walmart["type_store"]
type_store
# Out:
# 0       Supercenter
# 1       Supercenter
# 2       Supercenter
# 3       Supercenter
# 4          Wal-Mart
# 5       Supercenter
# 6       Supercenter
# 7       Supercenter
# 8       Supercenter
# 9       Supercenter
# 10      Supercenter
# 11      Supercenter
# 12      Supercenter
# 13         Wal-Mart
# 14      Supercenter
# 15      Supercenter
# 16      Supercenter
# 17      Supercenter
# 18      Supercenter
# 19         Wal-Mart
# 20      Supercenter
# 21      Supercenter
# 22      Supercenter
# 23         Wal-Mart
# 24      Supercenter
# 25      Supercenter
# 26      Supercenter
# 27      Supercenter
# 28      Supercenter
# 29      Supercenter
#            ...
# 2962    Supercenter
# 2963    Supercenter
# 2964    Supercenter
# 2965    Supercenter
# 2966       Wal-Mart
# 2967    Supercenter
# 2968    Supercenter
# 2969       Wal-Mart
# 2970    Supercenter
# 2971    Supercenter
# 2972    Supercenter
# 2973    Supercenter
# 2974    Supercenter
# 2975    Supercenter
# 2976    Supercenter
# 2977    Supercenter
# 2978    Supercenter
# 2979    Supercenter
# 2980    Supercenter
# 2981    Supercenter
# 2982    Supercenter
# 2983    Supercenter
# 2984    Supercenter
# 2985    Supercenter
# 2986    Supercenter
# 2987    Supercenter
# 2988    Supercenter
# 2989       Wal-Mart
# 2990    Supercenter
# 2991       Wal-Mart
# Name: type_store, Length: 2992, dtype: object

# %% [markdown]
# You can display rows that have a certain value for a column. In the cell below, create a new dataframe called "onlyWalmarts" that is the subset of the walmart dataframe where type_store equals "Wal-Mart". Print the first 10 rows of this new dataframe. How many stores have the type "Wal-Mart"?<br>
# <b>Hint:</b> To find the number of stores, find the number of rows

# %%
# your code here

# find stores with type_store "Wal-Mart"
onlyWalmarts = walmart.loc[walmart["type_store"] == "Wal-Mart"]

# display the first 10 rows of onlyWalmart
onlyWalmarts.head(10)
# Out:
#     storenum OPENDATE date_super  conversion  st  county  \
# 4          7  10/1/67        NaN         NaN   5     119
# 13        18  11/1/69        NaN         NaN   5      67
# 19        26  11/1/70        NaN         NaN  20     103
# 23        32   6/1/71        NaN         NaN  29     213
# 35        39   3/1/72        NaN         NaN  20      11
# 38        44   2/1/72        NaN         NaN  29     131
# 42        55  10/1/72        NaN         NaN   5      83
# 48        57  10/1/72        NaN         NaN   5      75
# 52        74  11/1/73        NaN         NaN   5      93
# 53        42   2/1/73        NaN         NaN  20     125
#
#                       STREETADDR            STRCITY STRSTATE  ZIPCODE  \
# 4         3801 CAMP ROBINSON RD.  North Little Rock       AR    72118
# 13  2500 MALCOLM ST/HWY 67 NORTH            Newport       AR    72112
# 19        3450 S. 4TH TRAFFICWAY        Leavenworth       KS    66048
# 23              2050 WEST HWY 76            Branson       MO    65616
# 35               2400 SOUTH MAIN         Fort Scott       KS    66701
# 38    1802 SOUTH BUSINESS HWY 54              Eldon       MO    65026
# 42                1555 EAST MAIN         Booneville       AR    72927
# 48                1600 WEST MAIN       Walnut Ridge       AR    72476
# 52       1051 WEST KEISER AVENUE            Osceola       AR    72370
# 53         1705 WEST 11TH STREET        Coffeyville       KS    67337
#
#    type_store        LAT       LON  MONTH  DAY  YEAR
# 4    Wal-Mart  34.813269 -92.30229     10    1  1967
# 13   Wal-Mart  35.586065 -91.24695     11    1  1969
# 19   Wal-Mart  39.298776 -94.93555     11    1  1970
# 23   Wal-Mart  36.644170 -93.25668      6    1  1971
# 35   Wal-Mart  37.823295 -94.73389      3    1  1972
# 38   Wal-Mart  38.311355 -92.58395      2    1  1972
# 42   Wal-Mart  35.105966 -93.97531     10    1  1972
# 48   Wal-Mart  36.068015 -90.94429     10    1  1972
# 52   Wal-Mart  35.696385 -90.02631     11    1  1973
# 53   Wal-Mart  37.041838 -95.61814      2    1  1973

# %%
# How many stores have the type "Wal-Mart"?

onlyWalRow = onlyWalmarts.shape[0]
print("There are", onlyWalRow, "stores with type 'Wal-Mart'")
# Out:
# There are 1046 stores with type 'Wal-Mart'

# %% [markdown]
# ### Part 3: Counting Wal-Marts with Pandas

# %% [markdown]
# Using the value_counts() function, you can find the number of occurrances of different values in a dataframe. In the cell below, find the number stores with types Wal-Mart and Supercenter. Cast the result into a dataframe called typeCount.
# <br>
# <b>Hint:</b> Use the pd.DataFrame() to cast the result to a dataframe.

# %%
# your code here
# https://stackoverflow.com/questions/35523635/extract-values-in-pandas-value-counts

typeCount = walmart["type_store"].value_counts()
typeCount = pd.DataFrame(typeCount)
typeCount
# Out:
#              type_store
# Supercenter        1946
# Wal-Mart           1046

# %% [markdown]
# Find the sum of the counts above. Is the sum the same as the number of rows that you found earlier?

# %%
# Find the Sum. 
summation = typeCount.sum(axis = 0)
summation
# Out:
# type_store    2992
# dtype: int64

# %% [markdown]
# #### Answer this question:
# Is it the answer you got the same as the number of rows of the walmart set? : YES

# %% [markdown]
# Now, using the value_counts() function again, find out how many stores were converted 1 or 0 times.

# %%
# your code here
conversionCount = walmart["conversion"].value_counts()
conversionCount = pd.DataFrame(conversionCount)
conversionCount
# Out:
#      conversion
# 1.0        1557
# 0.0         389

# %% [markdown]
# Find the sum of the counts above. Is the sum the same number of rows you found earlier?

# %%
# your code here

#find the sum
conversionSum = conversionCount.sum(axis = 0)

print("There are", conversionSum, "rows in the conversionCount dataframe.")
# Out:
# There are conversion    1946
# dtype: int64 rows in the conversionCount dataframe.

# %% [markdown]
# #### Answer this question:
# Is it the answer you got the same as the number of rows of the walmart set? : NO

# %% [markdown]
# If you look closely at the walmart data, you'll see that some of rows have NaN values for "conversion." Those rows weren't counted in the conversionCount data above. In the next cell, find the number of stores that don't have any "conversion" data.
# <br>
# <b>Hint:</b> Use the .isnull( ) function

# %%
# your code here

# find all all the rows with NaN value for conversion
noConversionData = walmart["conversion"].isnull()
# find the number of stores with a NaN value for conversion
noConversion = noConversionData.sum()
print("There are", noConversion, "stores with no conversion data")
# Out:
# There are 1046 stores with no conversion data

# %% [markdown]
# Add the number that you found from the conversion counts and the stores with no conversion data. Does it now equal the total number of rows of the walmart set?

# %%
# find the sum
summation = conversionSum + noConversion
summation
# Out:
# conversion    2992
# dtype: int64

# %% [markdown]
# #### Answer this question:
# Is it the answer you got the same as the number of rows of the walmart set? : YES

# %% [markdown]
# ### Part 4: What does it all mean?
# A question I hope that you've been asking yourself (if you haven't already figured it out) is WHY are there stores with NaN values for "conversion." Hasn't each store either been converted 1 or 0 times? What does this mean? For the next part, I using the process that you've been using for the first 3 parts, find out what types of stores have values of 1, 0, and NaN. <i><u>Are they stores that got converted to Supercenters? Are they stores that were built as Supercenters? Are they stores that were just never converted into Supercenters? </i></u>You can explore the data however you'd like, but I'd suggest you make use of the functions that you've been using and that you look at the data.
#
# <b>Hint:</b> Make 3 different data frames for stores with conversion values of 1, 0, or NaN. You already made the dataframe for the stores with NaN values. I would personally take a look at the OPENDATE, date_super, and type_store fields. If you forget what those fields mean, look at my key at the top of this page.

# %%
# Stores with NaN for conversion
noConversionData = walmart.loc[walmart["conversion"].isnull()]
noConversionData
# Out:
#       storenum  OPENDATE date_super  conversion  st  county  \
# 4            7   10/1/67        NaN         NaN   5     119
# 13          18   11/1/69        NaN         NaN   5      67
# 19          26   11/1/70        NaN         NaN  20     103
# 23          32    6/1/71        NaN         NaN  29     213
# 35          39    3/1/72        NaN         NaN  20      11
# 38          44    2/1/72        NaN         NaN  29     131
# 42          55   10/1/72        NaN         NaN   5      83
# 48          57   10/1/72        NaN         NaN   5      75
# 52          74   11/1/73        NaN         NaN   5      93
# 53          42    2/1/73        NaN         NaN  20     125
# 59          64    2/1/73        NaN         NaN  47      75
# 67          78    9/1/73        NaN         NaN  29     225
# 68          80    6/1/73        NaN         NaN  29      19
# 75         107   10/1/74        NaN         NaN  47     183
# 81          84    5/1/74        NaN         NaN   5      95
# 83         104    7/1/74        NaN         NaN  47      53
# 89          92    4/1/74        NaN         NaN  29     109
# 90          93   10/1/74        NaN         NaN  47     167
# 97          98    2/1/75        NaN         NaN  22      67
# 99         108    2/1/75        NaN         NaN  40      83
# 104        114    4/1/75        NaN         NaN  28     117
# 105        116    8/1/75        NaN         NaN  22      17
# 106        117    6/1/75        NaN         NaN  40      89
# 116        120    3/1/76        NaN         NaN  47      53
# 117        136    4/1/76        NaN         NaN  40      71
# 120        139    7/1/76        NaN         NaN  40      87
# 122        126    3/1/76        NaN         NaN   5     119
# 128        145   10/1/76        NaN         NaN  29     163
# 131        142    5/1/76        NaN         NaN  48     387
# 134        132    2/1/76        NaN         NaN  40      73
# ...        ...       ...        ...         ...  ..     ...
# 2810      5276   8/25/04        NaN         NaN  17      31
# 2827      2956   9/15/04        NaN         NaN  17     197
# 2830      5338   5/19/04        NaN         NaN   6      73
# 2833      2867   8/25/04        NaN         NaN  26      65
# 2846      3336   11/9/05        NaN         NaN  26     163
# 2864      5457   8/24/05        NaN         NaN   6       1
# 2866      5440   4/13/05        NaN         NaN  41       5
# 2868      5352  10/26/05        NaN         NaN  17      89
# 2869      2643   9/14/05        NaN         NaN  27     163
# 2870      2989   8/24/05        NaN         NaN   6       1
# 2875      5450   7/20/05        NaN         NaN  24      15
# 2879      5442   5/25/05        NaN         NaN  17      43
# 2881      5162   1/26/05        NaN         NaN   6      37
# 2882      3420   1/26/05        NaN         NaN  36      59
# 2886      3404   3/23/05        NaN         NaN  27     123
# 2901      5240   1/26/05        NaN         NaN  36     109
# 2912      3322   7/20/05        NaN         NaN  55     133
# 2916      5280   1/26/05        NaN         NaN  26      77
# 2926      5344   5/11/05        NaN         NaN  24       5
# 2932      5404   9/14/05        NaN         NaN  17      31
# 2934      3364   1/26/05        NaN         NaN  27      37
# 2941      5495   5/11/05        NaN         NaN  42      45
# 2946      5072   6/15/05        NaN         NaN   6      37
# 2947      5073   1/26/05        NaN         NaN  53      33
# 2948      5394   8/24/05        NaN         NaN   6     107
# 2954      5305  10/26/05        NaN         NaN   6      73
# 2966      5436   1/31/06        NaN         NaN  10       3
# 2969      5131   1/25/06        NaN         NaN  42      17
# 2989      5485   1/27/06        NaN         NaN  17      31
# 2991      5193   1/31/06        NaN         NaN   6      65
#
#                           STREETADDR               STRCITY STRSTATE  ZIPCODE  \
# 4             3801 CAMP ROBINSON RD.     North Little Rock       AR    72118
# 13      2500 MALCOLM ST/HWY 67 NORTH               Newport       AR    72112
# 19            3450 S. 4TH TRAFFICWAY           Leavenworth       KS    66048
# 23                  2050 WEST HWY 76               Branson       MO    65616
# 35                   2400 SOUTH MAIN            Fort Scott       KS    66701
# 38        1802 SOUTH BUSINESS HWY 54                 Eldon       MO    65026
# 42                    1555 EAST MAIN            Booneville       AR    72927
# 48                    1600 WEST MAIN          Walnut Ridge       AR    72476
# 52           1051 WEST KEISER AVENUE               Osceola       AR    72370
# 53             1705 WEST 11TH STREET           Coffeyville       KS    67337
# 59                  100 SOUTH DUPREE           Brownsville       TN    38012
# 67    1331 SPUR DR/ BUS. RT US HWY66            Marshfield       MO    65706
# 68    401 N STADIUM BL/BISCAYNE MALL              Columbia       MO    65201
# 75                850 WAL-MART DRIVE                Martin       TN    38237
# 81      PINECREST PLAZA SHOPPING CTR              Brinkley       AR    72021
# 83            15427 SO. FIRST STREET                 Milan       TN    38358
# 89                3020 SOUTH ELLIOTT                Aurora       MO    65605
# 90           975 US HIGHWAY 51 NORTH             Covington       TN    38019
# 97                 2030 EAST MADISON               Bastrop       LA    71220
# 99               1618 SOUTH DIVISION               Guthrie       OK    73044
# 104               200 WALMART CIRCLE            Booneville       MS    38829
# 105            929 SOUTH PINE STREET                Vivian       LA    71082
# 106             501 SOUTH PARK DRIVE            Broken Bow       OK    74728
# 116        2716 NORTH CENTRAL AVENUE              Humboldt       TN    38343
# 117                 1219 WEST DOOLIN             Blackwell       OK    74631
# 120          1620 NORTH GREEN AVENUE               Purcell       OK    73080
# 122             700 SOUTH BOWMAN BLV           Little Rock       AR    72211
# 128            3310 W GEORGIA STREET             Louisiana       MO    63353
# 131                 2204 HWY 82 WEST           Clarksville       TX    75426
# 134           1213 SOUTH MAIN STREET            Kingfisher       OK    73750
# ...                              ...                   ...      ...      ...
# 2810            1555 NORTH RAND ROAD              Palatine       IL    60074
# 2827          1401 ILLINOIS ROUTE 59            Joliet (N)       IL    60431
# 2830            4840 SHAWLINE STREET          Kearney Mesa       CA    92111
# 2833          3225 TOWNE CENTRE BLVD           Lansing (N)       MI    48912
# 2846                23800 Allen Road             Woodhaven       MI    48183
# 2864            8400 EDGEWATER DRIVE           Oakland (S)       CA    94612
# 2866       10000 SOUTHEAST 82ND AVE.             Clackamas       OR    97266
# 2868            801 NO. RANDALL ROAD               Batavia       IL    60510
# 2869               10240 HUDSON ROAD              Woodbury       MN    55129
# 2870               44009 OSGOOD ROAD               Fremont       CA    94539
# 2875             75 NORTH EAST PLAZA            North East       MD    21901
# 2879        1050 NORTH ROHLWING ROAD               Addison       IL    60101
# 2881     27931 KELLY JOHNSON PARKWAY     Santa Clarita (W)       CA    91355
# 2882           1220 OLD COUNTRY ROAD                Nassau       NY    11590
# 2886        3800 SILVER LAKE ROAD NE           St. Anthony       MN    55421
# 2901   135 FAIRGROUNDS MEMORIAL PKWY                Ithaca       NY    14850
# 2912               411 PEWAUKEE ROAD              Pewaukee       WI    53072
# 2916                8350 SHAVER ROAD               Portage       MI    49024
# 2926       1238 PUTTY HILL AVE STE 5                Towson       MD    21286
# 2932               103 HOLBROOK ROAD              Glenwood       IL    60425
# 2934    1644 SOUTH ROBERT STREET SO.         West St. Paul       MN    55118
# 2941           50 NORTH MACDADE BLVD             Glenolden       PA    19036
# 2946       19503 SOUTH NORMANDIE AVE  Los Angeles (So Bay)       CA    90502
# 2947     17432 SOUTHEAST 270TH PLACE             Covington       WA    98042
# 2948           770 WEST EL MONTE WAY                Dinuba       CA    93618
# 2954                   1150 BROADWAY       Chula Vista (S)       CA    91911
# 2966             1251 Centerville Rd            Wilmington       DE    19808
# 2969               3461 Horizon Blvd              Bensalem       PA    19020
# 2989                  2500 W 95th St        Evergreen Park       IL    60805
# 2991           12721 Moreno Beach Dr         Moreno Valley       CA    92555
#
#      type_store        LAT        LON  MONTH  DAY  YEAR
# 4      Wal-Mart  34.813269  -92.30229     10    1  1967
# 13     Wal-Mart  35.586065  -91.24695     11    1  1969
# 19     Wal-Mart  39.298776  -94.93555     11    1  1970
# 23     Wal-Mart  36.644170  -93.25668      6    1  1971
# 35     Wal-Mart  37.823295  -94.73389      3    1  1972
# 38     Wal-Mart  38.311355  -92.58395      2    1  1972
# 42     Wal-Mart  35.105966  -93.97531     10    1  1972
# 48     Wal-Mart  36.068015  -90.94429     10    1  1972
# 52     Wal-Mart  35.696385  -90.02631     11    1  1973
# 53     Wal-Mart  37.041838  -95.61814      2    1  1973
# 59     Wal-Mart  35.590558  -89.26090      2    1  1973
# 67     Wal-Mart  37.330958  -92.90929      9    1  1973
# 68     Wal-Mart  38.926838  -92.29003      6    1  1973
# 75     Wal-Mart  36.353928  -88.84191     10    1  1974
# 81     Wal-Mart  34.867846  -91.19271      5    1  1974
# 83     Wal-Mart  35.916722  -88.76628      7    1  1974
# 89     Wal-Mart  36.918018  -93.71063      4    1  1974
# 90     Wal-Mart  35.560622  -89.64201     10    1  1974
# 97     Wal-Mart  32.814969  -91.90678      2    1  1975
# 99     Wal-Mart  35.857303  -97.43176      2    1  1975
# 104    Wal-Mart  34.653448  -88.53751      4    1  1975
# 105    Wal-Mart  32.849008  -93.97599      8    1  1975
# 106    Wal-Mart  34.142978  -94.80269      6    1  1975
# 116    Wal-Mart  35.825299  -88.90218      3    1  1976
# 117    Wal-Mart  36.800787  -97.29289      4    1  1976
# 120    Wal-Mart  35.017656  -97.39646      7    1  1976
# 122    Wal-Mart  34.749723  -92.41345      3    1  1976
# 128    Wal-Mart  39.449012  -91.07518     10    1  1976
# 131    Wal-Mart  33.626445  -95.03534      5    1  1976
# 134    Wal-Mart  35.856216  -97.93743      2    1  1976
# ...         ...        ...        ...    ...  ...   ...
# 2810   Wal-Mart  42.143819  -88.02546      8   25  2004
# 2827   Wal-Mart  41.524930  -88.19022      9   15  2004
# 2830   Wal-Mart  32.804972 -117.16871      5   19  2004
# 2833   Wal-Mart  42.734434  -84.52497      8   25  2004
# 2846   Wal-Mart  42.137071  -83.21446     11    9  2005
# 2864   Wal-Mart  37.809427 -122.27172      8   24  2005
# 2866   Wal-Mart  45.478641 -122.56233      4   13  2005
# 2868   Wal-Mart  41.845228  -88.30995     10   26  2005
# 2869   Wal-Mart  44.896938  -92.90241      9   14  2005
# 2870   Wal-Mart  37.515014 -121.92916      8   24  2005
# 2875   Wal-Mart  39.593813  -75.95602      7   20  2005
# 2879   Wal-Mart  41.931573  -88.00222      5   25  2005
# 2881   Wal-Mart  34.406519 -118.56214      1   26  2005
# 2882   Wal-Mart  40.756287  -73.57536      1   26  2005
# 2886   Wal-Mart  45.050434  -93.25007      3   23  2005
# 2901   Wal-Mart  42.449454  -76.49685      1   26  2005
# 2912   Wal-Mart  43.076953  -88.26800      7   20  2005
# 2916   Wal-Mart  42.216541  -85.61773      1   26  2005
# 2926   Wal-Mart  39.399639  -76.58418      5   11  2005
# 2932   Wal-Mart  41.544584  -87.61289      9   14  2005
# 2934   Wal-Mart  44.903165  -93.10026      1   26  2005
# 2941   Wal-Mart  39.902045  -75.29371      5   11  2005
# 2946   Wal-Mart  33.833416 -118.29198      6   15  2005
# 2947   Wal-Mart  47.363382 -122.11451      1   26  2005
# 2948   Wal-Mart  36.538017 -119.38887      8   24  2005
# 2954   Wal-Mart  32.608799 -117.06070     10   26  2005
# 2966   Wal-Mart  39.734279  -75.66310      1   31  2006
# 2969   Wal-Mart  40.103860  -74.93734      1   25  2006
# 2989   Wal-Mart  41.719933  -87.70249      1   27  2006
# 2991   Wal-Mart  33.922823 -117.16837      1   31  2006
#
# [1046 rows x 16 columns]

# %%
# you can put more code here

# explore the data however you'd like.
# https://stackoverflow.com/questions/16729574/how-to-get-a-value-from-a-cell-of-a-dataframe

# create data frame of walmarts with date_super is null
date_super_NA = walmart["date_super"].isnull()
no_date_super_NA = date_super_NA.sum(axis = 0)

# check to see if the number of stores that have no conversion date are the same as ones with null for date_super
if(no_date_super_NA == noConversion):
    print("There is the same number of no conversion data as stores that have no dates for being turned into a super store")

# Check to see how many walmarts there are (that aren't super centers)
print("There are ", no_date_super_NA, " stores with no conversion data")
walmarts = typeCount.at["Wal-Mart", "type_store"]
print("There are " + str(walmarts) + " Wal-Marts")
# Out:
# There is the same number of no conversion data as stores that have no dates for being turned into a super store
# There are  1046  stores with no conversion data
# There are 1046 Wal-Marts

# %% [markdown]
# Because of the above cell it appears that the stores that have no conversion data are all Wal-Marts and not Super Centers.

# %%
# your code here 

# make a data frame of stores with 1 as a conversion value
convertedStores =  walmart.loc[walmart["conversion"] == 1]

convertedStores[:]
# Out:
#       storenum  OPENDATE date_super  conversion  st  county  \
# 0            1    7/1/62     3/1/97         1.0   5       7
# 1            2    8/1/64     3/1/96         1.0   5       9
# 2            4    8/1/65     3/1/02         1.0   5       7
# 3            8   10/1/67     3/1/93         1.0   5      29
# 5           10    7/1/68     3/1/98         1.0  40      21
# 6           13   11/1/68     3/1/96         1.0  29      97
# 7           12    7/1/68     3/1/94         1.0  40     131
# 8           11    3/1/68    2/20/02         1.0   5       5
# 9            9    3/1/68     3/1/00         1.0  29     143
# 10          15    5/1/69     3/1/95         1.0  29      91
# 11          17    5/1/69     3/1/93         1.0  29     145
# 12          16    4/1/69     3/1/00         1.0   5      33
# 14          14    4/1/69     3/1/99         1.0  29     105
# 15          20   10/1/70     3/1/99         1.0  29      83
# 16          22   10/1/70    5/18/05         1.0  40      97
# 17          21    3/1/70    8/22/01         1.0  29     169
# 18          23   11/1/70     3/1/94         1.0  22      61
# 20          30   11/1/71    5/18/05         1.0  29     207
# 21          27    2/1/71     3/1/99         1.0  29      65
# 22          33    6/1/71    9/17/03         1.0   5      61
# 24          29    8/1/71     3/1/89         1.0  29      51
# 25          31    6/1/71     3/1/95         1.0  40      79
# 26          24    4/1/71     3/1/99         1.0   5     119
# 27          25    2/1/71    5/18/05         1.0  29       7
# 28          34   11/1/71    5/21/03         1.0  29     217
# 29          35   10/1/71    3/17/04         1.0  20     161
# 30          36   11/1/71     3/1/96         1.0   5      55
# 31          37    9/1/71     3/1/89         1.0  29     187
# 32          38   12/9/71    3/17/04         1.0  40      89
# 33          40   11/1/71     3/1/95         1.0  29     175
# ...        ...       ...        ...         ...  ..     ...
# 2495      2857   2/28/01    2/28/01         1.0  29     165
# 2496      2991  10/24/01   10/24/01         1.0  48     491
# 2498      2921   2/28/01    2/28/01         1.0  49      57
# 2501      2978   2/28/01    2/28/01         1.0  48     439
# 2502      2862   2/28/01    2/28/01         1.0  16       1
# 2503      2939   1/24/01    1/24/01         1.0  28     121
# 2504      2778   1/24/01    1/24/01         1.0   4      21
# 2505      2923   1/24/01    1/24/01         1.0  30     111
# 2510      3262  10/24/01   10/24/01         1.0  39      59
# 2513      2789   1/24/01    1/24/01         1.0  12      99
# 2514      2968   1/24/01    1/24/01         1.0  21      41
# 2515      3213   1/24/01    1/24/01         1.0  48     339
# 2517      2882   1/24/01   11/16/05         1.0  27      53
# 2518      3261  10/24/01    9/21/05         1.0  53       5
# 2519      2796  10/24/01   10/24/01         1.0  12     103
# 2520      3214   1/24/01    1/24/01         1.0  51     800
# 2521      2963  10/24/01   10/24/01         1.0  12      11
# 2522      2884   1/24/01    1/24/01         1.0  32       3
# 2529      2927   1/24/01    9/21/05         1.0  41      51
# 2531      2929   2/28/01    2/28/01         1.0  37      51
# 2532      2894   2/28/01    2/28/01         1.0  24      23
# 2535      2932   1/24/01    1/24/01         1.0  47      93
# 2575      3258   5/15/02    11/2/05         1.0  41      39
# 2577      3274   8/14/02    8/14/02         1.0  48     439
# 2618      3518   7/17/02    7/17/02         1.0  48     479
# 2677      5139  10/29/03    11/2/05         1.0   6      95
# 2679      5136   8/20/03    11/2/05         1.0   6     115
# 2696      3513   3/19/03    11/2/05         1.0  27     139
# 2698      5079   6/18/03    6/18/03         1.0  28      47
# 2939      3431   8/24/05    8/24/05         1.0  48     367
#
#                       STREETADDR              STRCITY STRSTATE  ZIPCODE  \
# 0               2110 WEST WALNUT               Rogers       AR    72756
# 1               1417 HWY 62/65 N             Harrison       AR    72601
# 2              2901 HWY 412 EAST       Siloam Springs       AR    72761
# 3          1621 NORTH BUSINESS 9            Morrilton       AR    72110
# 5            2020 SOUTH MUSKOGEE            Tahlequah       OK    74464
# 6                 2705 GRAND AVE             Carthage       MO    64836
# 7           1500 LYNN RIGGS BLVD            Claremore       OK    74017
# 8              65 WAL-MART DRIVE        Mountain Home       AR    72653
# 9                1303 SOUTH MAIN             Sikeston       MO    63801
# 10     1310 PREACHER RD/HGWY 160          West Plains       MO    65775
# 11               3200 LUSK DRIVE               Neosho       MO    64850
# 12          2214 FAYETTEVILLE RD            Van Buren       AR    72956
# 14              1800 S JEFFERSON              Lebanon       MO    65536
# 15                1712 EAST OHIO              Clinton       MO    64735
# 16            4901 SO. MILL ROAD                Pryor       OK    74361
# 17            185 ST ROBERT BLVD           St. Robert       MO    65584
# 18      1201 N SERVICE ROAD EAST               Ruston       LA    71270
# 20         2025 BUS. HWY 60 WEST               Dexter       MO    63841
# 21              1101 HWY 32 WEST                Salem       MO    65560
# 22               1710 SO. 4TH ST            Nashville       AR    71852
# 24         724 STADIUM WEST BLVD       Jefferson City       MO    65109
# 25               3108 N BROADWAY               Poteau       OK    74953
# 26           2000 JOHN HARDEN DR         Jacksonville       AR    72076
# 27             4820 SO. CLARK ST               Mexico       MO    65265
# 28           2250 LINCOLN AVENUE               Nevada       MO    64772
# 29      101 EAST BLUEMONT AVENUE            Manhattan       KS    66502
# 30       2802 WEST KINGS HIGHWAY            Paragould       AR    72450
# 31              701 WALTON DRIVE           Farmington       MO    63640
# 32        1907 SE WASHINGTON ST.               Idabel       OK    74745
# 33              1301 HWY 24 EAST              Moberly       MO    65270
# ...                          ...                  ...      ...      ...
# 2495       8551 N.BOARDWALK AVE.     Kansas City (NW)       MO    64154
# 2496              201 WALTON WAY           Cedar Park       TX    78613
# 2498        534 HARRISVILLE ROAD                Ogden       UT    84404
# 2501          7451 MCCART AVENUE       Fort Worth (S)       TX    76133
# 2502     4051 EAST FAIRVIEW AVE.             Meridian       ID    83642
# 2503       200 MARKETPLACE DRIVE             Richland       MS    39218
# 2504       1695 NO. ARIZONA BLVD             Coolidge       AZ    85228
# 2505            1649 MAIN STREET             Billings       MT    59105
# 2510        61205 SOUTHGATE PKWY            Cambridge       OH    43725
# 2513       3200 OLD BOYNTON ROAD    Boynton Beach (E)       FL    33436
# 2514             200 FLOYD DRIVE           Carrollton       KY    41008
# 2515     3040 COLLEGE PARK DRIVE    The Woodlands (N)       TX    77384
# 2517       9451 DUNKIRK LANE NO.          Maple Grove       MN    55311
# 2518       2801 DUPORTAIL STREET             Richland       WA    99352
# 2519             3801 TAMPA ROAD              Oldsmar       FL    34677
# 2520          6259 COLLEGE DRIVE          Suffolk (N)       VA    23435
# 2521      6001 CORAL RIDGE DRIVE    Coral Springs (W)       FL    33076
# 2522     8060 WEST TROPICAL PKWY            Las Vegas       NV    89149
# 2529       23500 N.E. SANDY BLVD         Wood Village       OR    97060
# 2531             3030 NORTH MAIN           Hope Mills       NC    28348
# 2532           13164 GARRETT HWY              Oakland       MD    21550
# 2535        10900 PARKSIDE DRIVE            Knoxville       TN    37922
# 2575       4550 WEST 11TH AVENUE           Eugene (W)       OR    97402
# 2577  9101 NORTH TARRANT PARKWAY  N.Richland Hills(N)       TX    76180
# 2618       2320 BOB BULLOCK LOOP          Laredo (SE)       TX    78043
# 2677       235 EAST DORSET DRIVE                Dixon       CA    95620
# 2679       1131 NORTH BEALE ROAD           Marysville       CA    95901
# 2696     8101 OLD CARRIAGE COURT             Shakopee       MN    55379
# 2698        1617 EAST BEACH BLVD       Pass Christian       MS    39571
# 2939     2801 EAST INTERSTATE 20          Hudson Oaks       TX    76087
#
#        type_store        LAT         LON  MONTH  DAY  YEAR
# 0     Supercenter  36.342235  -94.071410      7    1  1962
# 1     Supercenter  36.236984  -93.093450      8    1  1964
# 2     Supercenter  36.179905  -94.502080      8    1  1965
# 3     Supercenter  35.156491  -92.758580     10    1  1967
# 5     Supercenter  35.923658  -94.971850      7    1  1968
# 6     Supercenter  37.168985  -94.311640     11    1  1968
# 7     Supercenter  36.327143  -95.611920      7    1  1968
# 8     Supercenter  36.329026  -92.357810      3    1  1968
# 9     Supercenter  36.891163  -89.583550      3    1  1968
# 10    Supercenter  36.719145  -91.874080      5    1  1969
# 11    Supercenter  36.864290  -94.390160      5    1  1969
# 12    Supercenter  35.456536  -94.345810      4    1  1969
# 14    Supercenter  37.678528  -92.647330      4    1  1969
# 15    Supercenter  38.364214  -93.760420     10    1  1970
# 16    Supercenter  36.294174  -95.302950     10    1  1970
# 17    Supercenter  37.827415  -92.135741      3    1  1970
# 18    Supercenter  32.524760  -92.646960     11    1  1970
# 20    Supercenter  36.784453  -89.974280     11    1  1971
# 21    Supercenter  37.630896  -91.514230      2    1  1971
# 22    Supercenter  33.985613  -93.852140      6    1  1971
# 24    Supercenter  38.568287  -92.253290      8    1  1971
# 25    Supercenter  35.052793  -94.618290      6    1  1971
# 26    Supercenter  34.879419  -92.122440      4    1  1971
# 27    Supercenter  39.179316  -91.884040      2    1  1971
# 28    Supercenter  37.838563  -94.350750     11    1  1971
# 29    Supercenter  39.184986  -96.569320     10    1  1971
# 30    Supercenter  36.065711  -90.510200     11    1  1971
# 31    Supercenter  37.779206  -90.414040      9    1  1971
# 32    Supercenter  33.883578  -94.831540     12    9  1971
# 33    Supercenter  39.420353  -92.434400     11    1  1971
# ...           ...        ...         ...    ...  ...   ...
# 2495  Supercenter  39.261679  -94.633530      2   28  2001
# 2496  Supercenter  30.501272  -97.830870     10   24  2001
# 2498  Supercenter  41.270319 -112.019320      2   28  2001
# 2501  Supercenter  32.655401  -97.377650      2   28  2001
# 2502  Supercenter  43.609434 -116.396420      2   28  2001
# 2503  Supercenter  32.230408  -90.162130      1   24  2001
# 2504  Supercenter  32.967829 -111.526170      1   24  2001
# 2505  Supercenter  45.836121 -108.468190      1   24  2001
# 2510  Supercenter  40.025859  -81.592430     10   24  2001
# 2513  Supercenter  26.530144  -80.104610      1   24  2001
# 2514  Supercenter  38.663328  -85.168030      1   24  2001
# 2515  Supercenter  30.233865  -95.496790      1   24  2001
# 2517  Supercenter  45.102133  -93.487570      1   24  2001
# 2518  Supercenter  46.279657 -119.281370     10   24  2001
# 2519  Supercenter  28.042799  -82.677370     10   24  2001
# 2520  Supercenter  36.848820  -76.465210      1   24  2001
# 2521  Supercenter  26.301160  -80.273100     10   24  2001
# 2522  Supercenter  36.266266 -115.286560      1   24  2001
# 2529  Supercenter  45.529551 -122.391560      1   24  2001
# 2531  Supercenter  34.954709  -78.937440      2   28  2001
# 2532  Supercenter  39.409861  -79.390150      2   28  2001
# 2535  Supercenter  35.875925  -84.126080      1   24  2001
# 2575  Supercenter  44.062231 -123.168040      5   15  2002
# 2577  Supercenter  32.855666  -97.218180      8   14  2002
# 2618  Supercenter  27.538658  -99.382740      7   17  2002
# 2677  Supercenter  38.427208 -121.813480     10   29  2003
# 2679  Supercenter  39.159730 -121.537350      8   20  2003
# 2696  Supercenter  44.776138  -93.525560      3   19  2003
# 2698  Supercenter  30.371623  -89.270380      6   18  2003
# 2939  Supercenter  32.703008  -97.748140      8   24  2005
#
# [1557 rows x 16 columns]

# %%
# you can put more code here
# https://stackoverflow.com/questions/16729574/how-to-get-a-value-from-a-cell-of-a-dataframe

# explore the data however you'd like.
# Are there any date_super null values?
date_super_NA = convertedStores["date_super"].isnull()
no_date_super_NA = date_super_NA.sum(axis = 0)
                                     
print(str(no_date_super_NA) + " converted stores have a null value for date_super")

# Is the number of converted stores the same as the number of super centers?
num_convertedStores = convertedStores.shape[0]
print("There are ", num_convertedStores, " converted stores.")

walmarts = typeCount.at["Supercenter", "type_store"]
print("There are " + str(walmarts) + " supercenters in all of the walmart data set")


storeCount = convertedStores["type_store"].value_counts()
storeCount = pd.DataFrame(storeCount)
storeCount = storeCount.at["Supercenter", "type_store"]
print("There are ", storeCount, " Supercenters in the converted stores data set.")
# Out:
# 0 converted stores have a null value for date_super
# There are  1557  converted stores.
# There are 1946 supercenters in all of the walmart data set
# There are  1557  Supercenters in the converted stores data set.

# %% [markdown]
# From the above cell we see that none of the converted stores have a null date for becoming a supercenter. We also see that the number of converted stores is the same as the number of supercenters. This leads me to believe that all converted stores are supercenters. We also see that the number of supercenters in the converted data is less than the total number of supercenters meaning that there are some supercenters not accounted for if we are just looking at the converted stores.

# %%
# your code here 

# make a data frame of stores with 0 as a conversion value
notConvertedStores = walmart.loc[walmart["conversion"] == 0]

notConvertedStores[:]
# Out:
#       storenum  OPENDATE date_super  conversion  st  county  \
# 1401        19    4/3/90     4/3/90         0.0  29      23
# 1875      1958   4/30/93    4/30/93         0.0  48     427
# 2133      2491   8/28/96    8/28/96         0.0  17     183
# 2151      2334   9/25/96    9/25/96         0.0  42      71
# 2152      2337   7/17/96    7/17/96         0.0  51      67
# 2161      2420  10/23/96   10/23/96         0.0  42     129
# 2165      2444   7/17/96    7/17/96         0.0  36      53
# 2173      2474   7/17/96    7/17/96         0.0  54      57
# 2174      2475   8/28/96    8/28/96         0.0  13     247
# 2194      2513   1/29/97    1/29/97         0.0  13     187
# 2196      2460   1/29/97    1/29/97         0.0  10       5
# 2197      2519   9/10/97    9/10/97         0.0  42     133
# 2205      1884   1/10/97    1/10/97         0.0  42      69
# 2216      2368   1/29/97    1/29/97         0.0  42      89
# 2217      2295   1/29/97    1/29/97         0.0  51      87
# 2219      2532   7/16/97    7/16/97         0.0  55     105
# 2257      2606   1/26/98    1/26/98         0.0  45      39
# 2279      2705   1/27/99    1/27/99         0.0  51     620
# 2280      2703   1/27/99    1/27/99         0.0  45      41
# 2282      2674  10/13/99   10/13/99         0.0  42      85
# 2283      2678   3/17/99    3/17/99         0.0  18     141
# 2284      2679   3/17/99    3/17/99         0.0  18      39
# 2285      2680   3/17/99    3/17/99         0.0  18     141
# 2288      2684   1/27/99    1/27/99         0.0  54     103
# 2298      2285  10/13/99   10/13/99         0.0  36      43
# 2304      2739   8/18/99    8/18/99         0.0   1       3
# 2310      2614  10/13/99   10/13/99         0.0  42      11
# 2323      2340   7/21/99    7/21/99         0.0  42      71
# 2347      2714   8/18/99    8/18/99         0.0  19      41
# 2349      2665   8/18/99    8/18/99         0.0  22     103
# ...        ...       ...        ...         ...  ..     ...
# 2958      3406   1/27/06    1/27/06         0.0  48     113
# 2959      5462   1/27/06    1/27/06         0.0  53      11
# 2960      5498   1/23/06    1/23/06         0.0  36      49
# 2961      5359   1/25/06    1/25/06         0.0  48     439
# 2962      3380   1/23/06    1/23/06         0.0  53      21
# 2963      3403   1/27/06    1/27/06         0.0  13     223
# 2964      3729   1/23/06    1/23/06         0.0  32      31
# 2965      3734   1/27/06    1/27/06         0.0  46      27
# 2967      3389   1/25/06    1/25/06         0.0  13     135
# 2968      3765   1/27/06    1/27/06         0.0  39     109
# 2970      3838   1/31/06    1/31/06         0.0  42       3
# 2971      3386   1/25/06    1/25/06         0.0   1     115
# 2972      5497   1/31/06    1/31/06         0.0  36      45
# 2973      3726   1/27/06    1/27/06         0.0  26      49
# 2974      3660   1/31/06    1/31/06         0.0  47      65
# 2975      2695   1/27/06    1/27/06         0.0  12      69
# 2976      5487   1/23/06    1/23/06         0.0  45      45
# 2977      3305   1/31/06    1/31/06         0.0  37     157
# 2978      3523   1/27/06    1/27/06         0.0   6      37
# 2979      3630   1/23/06    1/23/06         0.0  19     113
# 2980      2852   1/31/06    1/31/06         0.0  54      51
# 2981      5370   1/31/06    1/31/06         0.0   8      13
# 2982      3608   1/31/06    1/31/06         0.0  39      85
# 2983      5253   1/31/06    1/31/06         0.0  51     550
# 2984      5471   1/31/06    1/31/06         0.0  39     139
# 2985      5346   1/23/06    1/23/06         0.0  37       1
# 2986      5313   1/23/06    1/23/06         0.0  29     183
# 2987      5403   1/27/06    1/27/06         0.0  17      19
# 2988      3347   1/23/06    1/23/06         0.0  12     105
# 2990      3425   1/27/06    1/27/06         0.0  48     201
#
#                          STREETADDR           STRCITY STRSTATE  ZIPCODE  \
# 1401                 333 S WESTWOOD      Poplar Bluff       MO    63901
# 1875                  4534 E HWY 83    Rio Grand City       TX    78582
# 2133       4101 N VERMILION SUITE A          Danville       IL    61834
# 2151          2034 LINCOLN HWY EAST     East Lampeter       PA    17602
# 2152      550 OLD FRANKLIN TURNPIKE       Rocky Mount       VA    24151
# 2161  100 SARA WAY/ROSTRAVER SQUARE      Belle Vernon       PA    15012
# 2165            2024 GENESEE STREET            Oneida       NY    13421
# 2173                R.R. #4, BOX 82            Keyser       WV    26726
# 2174             1436 DOGWOOD DRIVE           Conyers       GA    30013
# 2194               270 WAL-MART WAY         Dahlonega       GA    30533
# 2196             751 NORTH DUAL HWY           Seaford       DE    19973
# 2197     698 SHREWSBURY COMMONS AVE        Shrewsbury       PA    17361
# 2205              900 COMMERCE BLVD      Dickson City       PA    18519
# 2216                355 LINCOLN AVE  East Stroudsburg       PA    18301
# 2217                  7901 BROOK RD          Richmond       VA    23227
# 2219            2785 MILWAUKEE ROAD            Beloit       WI    53511
# 2257   721 US HWY 321 BYPASS UNIT 1         Winnsboro       SC    29180
# 2279              1500 ARMORY DRIVE          Franklin       VA    23851
# 2280         2014 SOUTH IRBY STREET      Florence (S)       SC    29505
# 2282             45 WILLIAMSON ROAD        Greenville       PA    16125
# 2283          316 INDIAN RIDGE ROAD         Mishawaka       IN    46545
# 2284       175 COUNTRY ROAD #6 WEST           Elkhart       IN    46514
# 2285              3701 PORTAGE ROAD        South Bend       IN    46628
# 2288       1142 SOUTH BRIDGE STREET  New Martinsville       WV    26155
# 2298         103 NORTH CAROLINE ST.          Herkimer       NY    13350
# 2304             701 MCMEANS AVENUE       Bay Minette       AL    36507
# 2310            5370 ALLENTOWN PIKE           Reading       PA    19560
# 2323           890 EAST MAIN STREET           Ephrata       PA    17522
# 2347              500 11TH ST. S.W.           Spencer       IA    51301
# 2349           167 NORTHSHORE BLVD.           Slidell       LA    70460
# ...                             ...               ...      ...      ...
# 2958              15220 Montfort Dr            Dallas       TX    75248
# 2959               430 SE 192nd Ave         Vancouver       WA    98683
# 2960                  7155 Rte 12 S          Lowville       NY    13367
# 2961                    721 Boyd Rd              Azle       TX    76020
# 2962             4820 North Road 68             Pasco       WA    99301
# 2963              3615 Marietta Hwy            Dallas       GA    30157
# 2964           5065 Pyramid Lake Rd            Sparks       NV    89436
# 2965              1207 Princeton St        Vermillion       SD    57069
# 2967           3435 Centerville Hwy        Snellville       GA    30039
# 2968                  1300 E Ash St             Piqua       OH    45356
# 2970         2010 Village Center Dr          Tarentum       PA    15084
# 2971   160 Springville Station Blvd       Springville       AL    35146
# 2972                25737 US Rte 11       Evans Mills       NY    13637
# 2973              6170 S Saginaw Rd       Grand Blanc       MI    48439
# 2974              3428 Cummings Hwy       Chattanooga       TN    37419
# 2975             1450 Johns Lake Rd          Clermont       FL    34711
# 2976                    9 Benton Rd    Travelers Rest       SC    29690
# 2977                6711 St Hwy 135           Mayodan       NC    27027
# 2978            26471 Carl Boyer Dr     Santa Clarita       CA    91350
# 2979                5491 Bus Hwy 51            Marion       IA    52302
# 2980            240 N Lafayette Ave       Moundsville       WV    26041
# 2981                   2514 Main St          Longmont       CO    80504
# 2982                6067 N Ridge Rd           Madison       OH    44057
# 2983           632 Grass Field Pkwy        Chesapeake       VA    23322
# 2984             2485 Possum Run Rd         Mansfield       OH    44903
# 2985            1318 Mebane Oaks Rd            Mebane       NC    27302
# 2986        6100 Ronald Reagan Blvd  Lake Saint Louis       MO    63367
# 2987            100 S High Cross Rd            Urbana       IL    61802
# 2988      7450 Cypress Gardens Blvd      Winter Haven       FL    33884
# 2990                9598 Rowlett Rd           Houston       TX    77034
#
#        type_store        LAT        LON  MONTH  DAY  YEAR
# 1401  Supercenter  36.759357  -90.41689      4    3  1990
# 1875  Supercenter  26.445982  -98.69332      4   30  1993
# 2133  Supercenter  40.175463  -87.61240      8   28  1996
# 2151  Supercenter  40.032664  -76.27575      9   25  1996
# 2152  Supercenter  36.980013  -79.88027      7   17  1996
# 2161  Supercenter  40.140248  -79.84251     10   23  1996
# 2165  Supercenter  43.079635  -75.64678      7   17  1996
# 2173  Supercenter  39.434856  -78.95987      7   17  1996
# 2174  Supercenter  33.633685  -83.98382      8   28  1996
# 2194  Supercenter  34.542098  -83.99718      1   29  1997
# 2196  Supercenter  38.643248  -75.61102      1   29  1997
# 2197  Supercenter  39.765405  -76.67748      9   10  1997
# 2205  Supercenter  41.462130  -75.62478      1   10  1997
# 2216  Supercenter  41.052199  -75.15936      1   29  1997
# 2217  Supercenter  37.606778  -77.44775      1   29  1997
# 2219  Supercenter  42.526464  -89.04291      7   16  1997
# 2257  Supercenter  34.369441  -81.08218      1   26  1998
# 2279  Supercenter  36.668255  -76.93945      1   27  1999
# 2280  Supercenter  34.142119  -79.74311      1   27  1999
# 2282  Supercenter  41.403462  -80.37424     10   13  1999
# 2283  Supercenter  41.681487  -86.16811      3   17  1999
# 2284  Supercenter  41.707616  -85.97605      3   17  1999
# 2285  Supercenter  41.700776  -86.30357      3   17  1999
# 2288  Supercenter  39.646099  -80.83465      1   27  1999
# 2298  Supercenter  43.038149  -74.98460     10   13  1999
# 2304  Supercenter  30.875697  -87.76592      8   18  1999
# 2310  Supercenter  40.407243  -75.91163     10   13  1999
# 2323  Supercenter  40.174994  -76.17619      7   21  1999
# 2347  Supercenter  43.150381  -95.14466      8   18  1999
# 2349  Supercenter  30.298048  -89.81176      8   18  1999
# ...           ...        ...        ...    ...  ...   ...
# 2958  Supercenter  32.968123  -96.78863      1   27  2006
# 2959  Supercenter  45.604075 -122.51035      1   27  2006
# 2960  Supercenter  43.794492  -75.46905      1   23  2006
# 2961  Supercenter  32.905693  -97.54845      1   25  2006
# 2962  Supercenter  46.270249 -119.09462      1   23  2006
# 2963  Supercenter  33.892504  -84.83460      1   27  2006
# 2964  Supercenter  39.624698 -119.70585      1   23  2006
# 2965  Supercenter  42.812664  -96.94651      1   27  2006
# 2967  Supercenter  33.822204  -84.03707      1   25  2006
# 2968  Supercenter  40.156514  -84.24213      1   27  2006
# 2970  Supercenter  40.613570  -79.78095      1   31  2006
# 2971  Supercenter  33.781133  -86.45052      1   25  2006
# 2972  Supercenter  44.091494  -75.82694      1   31  2006
# 2973  Supercenter  42.925677  -83.63585      1   27  2006
# 2974  Supercenter  35.031674  -85.37276      1   31  2006
# 2975  Supercenter  28.545742  -81.74805      1   27  2006
# 2976  Supercenter  35.018511  -82.43224      1   23  2006
# 2977  Supercenter  36.421448  -79.97458      1   31  2006
# 2978  Supercenter  34.481172 -118.42821      1   27  2006
# 2979  Supercenter  42.042648  -91.58262      1   23  2006
# 2980  Supercenter  39.912923  -80.73701      1   31  2006
# 2981  Supercenter  40.160138 -105.01772      1   31  2006
# 2982  Supercenter  41.800630  -81.06021      1   31  2006
# 2983  Supercenter  36.687543  -76.22905      1   31  2006
# 2984  Supercenter  40.766589  -82.51869      1   31  2006
# 2985  Supercenter  36.111449  -79.27142      1   23  2006
# 2986  Supercenter  38.796601  -90.78525      1   23  2006
# 2987  Supercenter  40.121648  -88.17649      1   27  2006
# 2988  Supercenter  27.997387  -81.68256      1   23  2006
# 2990  Supercenter  29.636430  -95.21789      1   27  2006
#
# [389 rows x 16 columns]

# %%
# you can put more code here
# https://stackoverflow.com/questions/16729574/how-to-get-a-value-from-a-cell-of-a-dataframe

# explore the data however you'd like.
# How many not converted stores are there?
notConverted = notConvertedStores.shape[0]

# How many supercenters are there in the not converted stores data?
storeCount_nc = notConvertedStores["type_store"].value_counts()
storeCount_nc = pd.DataFrame(storeCount_nc)
storeCount_nc = storeCount_nc.at["Supercenter", "type_store"]

# Do the number of supercenters in not converted data plus those in converted data equal the total number of supercenters?
summation = storeCount + storeCount_nc
totSupercenters = typeCount.at["Supercenter", "type_store"]

if(summation == totSupercenters):
    print("The number of supercenters not converted and the number of supercenters converted equals the total number of supercenters in the data")

# Is the opening date the same date as date_super?
# http://pandas.pydata.org/pandas-docs/version/0.18/generated/pandas.DataFrame.equals.html
state = notConvertedStores["OPENDATE"].equals(notConvertedStores["date_super"])
print("It is ", state, " that the open date equals the date the store became a super")
# Out:
# The number of supercenters not converted and the number of supercenters converted equals the total number of supercenters in the data
# It is  True  that the open date equals the date the store became a super

# %% [markdown]
# ### Answer the following questions:
#
# 1. <b>Decribe the stores with 1 as a conversion value:</b>
# The stores that have 1 as a conversion value started off as Wal-Marts and were  converted to supercenters.
#
# 2. <b>Describe the stores with 0 as a conversion value:</b>
# The stores that have 0 as a conversion value were built as supercenters to begin with. They were never Wal-Marts
#
# 3. <b>Describe the stores with NaN as a conversion value:</b>
# The stores with NaN as conversion values were built as Wal-Marts and have remained Wal-Marts

# %% [markdown]
# ## Problem 2:
# ### Created by: Kaleigh
# ### Undergraduate 2.5 points Graduate 2 points

# %% [markdown]
# ---
# ## Winter Olympic Games
# By: Kaleigh
#
# Source: https://www.kaggle.com/the-guardian/olympic-games/data
#
# The dataset contains information on winter olympic games from 1924 to 2014.  Note: The dataset uses country codes rather than the complete country names.  If you would like to learn more about the dataset or know which codes correspond to which countries, you can find that information in the "dictionary.csv" file located at the link above.

# %% [markdown]
# ### 1) Load Dataset
#
# - Load the "winter.csv" file as a pandas dataframe.
# - Display the **first 5** rows of the dataframe.
# - Display the **last 5** rows of the dataframe.

# %%
# Your Code Here
df = pd.read_csv("winter.csv")
df.head()
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %%
df.tail()
# Out:
#       Year   City   Sport Discipline             Athlete Country Gender  \
# 5765  2014  Sochi  Skiing  Snowboard        JONES, Jenny     GBR  Women
# 5766  2014  Sochi  Skiing  Snowboard     ANDERSON, Jamie     USA  Women
# 5767  2014  Sochi  Skiing  Snowboard  MALTAIS, Dominique     CAN  Women
# 5768  2014  Sochi  Skiing  Snowboard        SAMKOVA, Eva     CZE  Women
# 5769  2014  Sochi  Skiing  Snowboard    TRESPEUCH, Chloe     FRA  Women
#
#                 Event   Medal
# 5765       Slopestyle  Bronze
# 5766       Slopestyle    Gold
# 5767  Snowboard Cross  Silver
# 5768  Snowboard Cross    Gold
# 5769  Snowboard Cross  Bronze

# %% [markdown]
# ### 2) Check for Null Values
# - If you find null values in the dataset, print 'True'
# - Otherwise, print 'False'

# %%
# Your Code Here
null = df.isnull()
null_count_horiz = null.sum(axis = 0)
null_count_tot = null_count_horiz.sum()

if null_count_tot:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# ### 3) Data Summary
# - Use describe() to display a summary table of your data.
# - Use either the 'include' parameter or 'exclude' parameter so that the table only includes the categorical columns (meaning it does not include the 'Year' column, which pandas interprets as numerical rather than categorical and is not particularly meaningful for our purposes).  I recommend reading the pandas documentation for describe().

# %%
# Your Code Here
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html
df.describe(include = [np.object])
# Out:
#          City   Sport  Discipline                 Athlete Country Gender  \
# count    5770    5770        5770                    5770    5770   5770
# unique     19       7          15                    3761      45      2
# top     Sochi  Skiing  Ice Hockey  BJOERNDALEN, Ole Einar     USA    Men
# freq      612    1781        1536                      13     653   3944
#
#              Event   Medal
# count         5770    5770
# unique          83       3
# top     Ice Hockey  Silver
# freq          1536    1930

# %%
# %matplotlib inline
series = df["Country"].value_counts()

# %% [markdown]
# ### 4) Bar Chart - Number of Medals Per Country
# Use the plotly library offline or cufflinks offline to create a bar chart displaying the number of medals per country.  (Country code on the x axis and number of medals on the y axis)

# %%
# Your Code Here
# https://plot.ly/ipython-notebooks/cufflinks/
import cufflinks as cf
cf.go_offline()
import plotly.plotly as py
series.iplot(kind = "bar", yTitle = "Num of Medals", xTitle = "Country", filename = "cufflinks/categorical-bar-chart")
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# <div id="deee6b2e-768c-4564-b673-63aac45b40e9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("deee6b2e-768c-4564-b673-63aac45b40e9", [{"type": "bar", "x": ["USA", "CAN", "NOR", "URS", "FIN", "SWE", "GER", "SUI", "AUT", "RUS", "ITA", "GDR", "TCH", "FRA", "NED", "FRG", "KOR", "CHN", "GBR", "CZE", "JPN", "EUN", "POL", "EUA", "SLO", "AUS", "LAT", "BLR", "BEL", "HUN", "CRO", "UKR", "LIE", "KAZ", "YUG", "EST", "BUL", "DEN", "SVK", "ROU", "PRK", "ESP", "LUX", "NZL", "UZB"], "y": [653, 625, 457, 440, 434, 433, 360, 285, 280, 263, 192, 162, 158, 152, 122, 94, 87, 82, 79, 75, 63, 60, 27, 21, 18, 15, 15, 15, 13, 12, 11, 11, 9, 7, 7, 7, 6, 5, 5, 2, 2, 2, 2, 1, 1], "name": "Country", "text": "", "marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "orientation": "v"}], {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "yaxis1": {"tickfont": {"color": "#4D5663"}, "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED", "showgrid": true, "title": "Num of Medals"}, "xaxis1": {"tickfont": {"color": "#4D5663"}, "gridcolor": "#E1E5ED", "titlefont": {"color": "#4D5663"}, "zerolinecolor": "#E1E5ED", "showgrid": true, "title": "Country"}, "titlefont": {"color": "#4D5663"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### 5) United States Olympic Medals
# - Create a dataframe containing only USA Olympic Medals
# - Display the **first 10** rows of the dataframe.

# %%
# Your Code Here
USA = df.loc[df["Country"] == "USA"]
USA.head(10)
# Out:
#     Year      City       Sport  Discipline                 Athlete Country  \
# 68  1924  Chamonix  Ice Hockey  Ice Hockey     ABEL, Clarence John     USA
# 69  1924  Chamonix  Ice Hockey  Ice Hockey       DRURY, Herbert L.     USA
# 70  1924  Chamonix  Ice Hockey  Ice Hockey               GERAN, N.     USA
# 71  1924  Chamonix  Ice Hockey  Ice Hockey       LACROIX, Alphonse     USA
# 72  1924  Chamonix  Ice Hockey  Ice Hockey    LANGLEY, John Arthur     USA
# 73  1924  Chamonix  Ice Hockey  Ice Hockey     LYONS, John Sharkey     USA
# 74  1924  Chamonix  Ice Hockey  Ice Hockey      MAC CARTHY, Justin     USA
# 75  1924  Chamonix  Ice Hockey  Ice Hockey           RICE, Willard     USA
# 76  1924  Chamonix  Ice Hockey  Ice Hockey   SMALL, Irving Wheeler     USA
# 77  1924  Chamonix  Ice Hockey  Ice Hockey  SYNNOTT, Francis Allen     USA
#
#    Gender       Event   Medal
# 68    Men  Ice Hockey  Silver
# 69    Men  Ice Hockey  Silver
# 70    Men  Ice Hockey  Silver
# 71    Men  Ice Hockey  Silver
# 72    Men  Ice Hockey  Silver
# 73    Men  Ice Hockey  Silver
# 74    Men  Ice Hockey  Silver
# 75    Men  Ice Hockey  Silver
# 76    Men  Ice Hockey  Silver
# 77    Men  Ice Hockey  Silver

# %% [markdown]
# ### 6) In which year did the USA win the most gold medals in the Bobsleigh competition?

# %%
# Your Code Here
# https://stackoverflow.com/questions/15138973/how-to-get-the-number-of-the-most-frequent-value-in-a-column
USA_bobsleigh = USA.loc[USA["Sport"] == "Bobsleigh"]
USA_bobsleigh["Year"].value_counts().idxmax()
# Out:
# 1932

# %% [markdown]
# ## Problem 3:
# ### Created by: Phil
# ### Undergraduate 2.5 points Graduate 2 points

# %% [markdown]
# ## West Nile Virus Cases
# By: Phil
#
# Source: https://www.healthdata.gov/dataset/west-nile-virus-cases-2006-present-1
#
# The state of California tracks the incidence of West Nile Virus on a monthly basis, by county. This dataset contains information on the number of cases each month since 2006. You can find more information about this dataset, and the disease, at the link above.
#
# Note that there is more than one way to do the exercises in this problem!
#
# We'll start with the usual boilerplate:

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### Loading the dataset
#
# Load the **wnvhumancases.csv** file into a pandas dataframe. How many total rows are there in the dataset?

# %%
# your code here
df = pd.read_csv('wnvhumancases.csv')
numRows = df.shape[0]
print("There are ", numRows, " rows in this data set")
# Out:
# There are  1740  rows in this data set

# %% [markdown]
# Display the first 10 rows of the dataset.

# %%
# your code here
df.head(10)
# Out:
#    Year  Week Reported   County  Positive Cases
# 0  2006             35  Alameda               1
# 1  2006             33    Butte               4
# 2  2006             34    Butte               1
# 3  2006             35    Butte              10
# 4  2006             36    Butte               2
# 5  2006             37    Butte               8
# 6  2006             38    Butte               3
# 7  2006             39    Butte               2
# 8  2006             43    Butte               1
# 9  2006             31   Colusa               1

# %%
df.tail()
# Out:
#       Year  Week Reported County  Positive Cases
# 1735  2017             38   Yolo               3
# 1736  2017             41   Yolo               1
# 1737  2017             45   Yolo               1
# 1738  2017             50   Yolo               1
# 1739  2017             50   Yuba               1

# %% [markdown]
# ### Some simple statistics

# %% [markdown]
# How many total positive cases of West Nile have been reported over the life of the dataset?

# %%
# your code here
totalPositive = df["Positive Cases"].sum()
totalPositive
# Out:
# 4897

# %% [markdown]
# To within 2 decimal places, how many cases would the average county expect to report in any month?

# %%
# your code here
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Index.min.html
# https://stackoverflow.com/questions/20457038/how-to-round-down-to-2-decimals-with-python
# https://stackoverflow.com/questions/455612/limiting-floats-to-two-decimal-points
numOfYears = df["Year"].value_counts().index.max() - df["Year"].value_counts().index.min() + 1
numOfCounties = len(df["County"].unique())
avgPerWeek = (totalPositive/ numOfYears)/52 # because 52 weeks in a year
avgPerCounty = round(avgPerWeek/ numOfCounties, 2)
format(avgPerCounty, '.2f')
# Out:
# '0.17'

# %% [markdown]
# ### West Nile Virus over time
#
# Add a plot that shows the total number of cases per year, with the year on the x-axis.

# %%
# your code here
# https://stackoverflow.com/questions/28236305/how-do-i-sum-values-in-a-column-that-match-a-given-condition-using-pandas
minimumYear = df["Year"].value_counts().index.min()
maximumYear = df["Year"].value_counts().index.max()
cases = []
for i in range(minimumYear, maximumYear + 1):
    cases.append(df.loc[df["Year"] == i, "Positive Cases"].sum())
years = np.arange(minimumYear, maximumYear + 1)

import matplotlib.pyplot as plt

plt.bar(years, cases)
plt.xlabel("Year")
plt.ylabel("Number of Cases")

# %% [markdown]
# It is clear from the graph which year had the highest total cases -- and also, that after a steep upward trajectory in the early years of the decade, the present trend appears to be down.
#
# What about the trend during the average year? Add a plot that shows the total number of cases of West Nile over the course of the year, combining the counts for all years of the dataset. (Hint: the values on the x-axis should be weeks, and your graph should be roughly bell-shaped with a peak between 350 and 400.

# %%
# your code here
df["Total Week"] = (df["Year"] - 2006)*52 + df["Week Reported"]
plt.bar(df["Total Week"], df["Positive Cases"])
plt.xlabel("Week")
plt.ylabel("Number of Cases")

# %% [markdown]
# Note which month appears to be the peak for cases of West Nile -- this most likely agrees with what you recall hearing on typical news reports throughout the year.

# %% [markdown]
# ## Problem 4:
# ### Created by: Joe
# ### Undergraduate 2.5 points Graduate 2 points

# %% [markdown]
# # Apples
#
# A sweet and delicious fruit.  But also, a computer ubiquitous to our class environment?
#
# Today, we'll explore historical apple stock data:

# %%
# the library du jour is pandas
import pandas as pd
import numpy as np

# %% [markdown]
# First things first.  We need to read in our dataset.  Read in the dataset "AAPL.csv" and store it to thet variable, df:

# %%
# given the supplied dataset, from yahoo finance, read in the csv file

# Your code here:
df =

# %% [markdown]
# Now that we've read in the data, give us a quick view of the first 6 rows of the data frame:

# %%
# Your code here:
df.

# %% [markdown]
# Something really important in our analysis, what are the data types.  Are our numbers actually numbers?  Use a pertinent method to list out what type of data we have:

# %%
# Your code here:
df.

# %% [markdown]
# This is problematic.  We need our data to be numeric if we're going to do computations on it.  Pandas will try to coerce data to the right type, but maybe we just need to help it out.  The following loop attempts to corce our numeric data to some sort of number:

# %%
for name in df.columns[1:]:
    df[name] = pd.to_numeric(df[name],errors="ignore")

# %% [markdown]
# In theory, we've converted everything that is a number into a proper float/number.  Are our datatypes now numbers of some sort?

# %%
# recheck our datatypes

# %% [markdown]
# No.  Let's take a look at our first 10 closes:

# %%
# Use the head command to find the first 5 closing prices
df.

# %% [markdown]
# To save you a little time, there is at least one instance where the data in the rows is non-numeric.

# %%
# August of 1981.  What was your deal, Apple?

# Use the .loc command to see the 165th entry in the data-frame.
df.loc[165]

# %% [markdown]
# Ok, we need to get rid of the 165th data entry.  Use the .drop( ) command to get rid of our bad data:

# %%
df = df.drop(165)

# alternatively, if you want to modify your dataframe in place, 
# you can include that as a parameter.

# df.drop(165, inplace = True)

# %% [markdown]
# Now let's check our data frame.  Is the bad data still there?

# %%
df.loc[164:166]

# %% [markdown]
# Nope!
#
# Lets recheck our data types:

# %%
df.dtypes

# %% [markdown]
# Let's try coercing our data to numbers again:

# %%
for name in df.columns[1:]:
    df[name] = pd.to_numeric(df[name],errors="ignore")

df.dtypes

# %% [markdown]
# Fortunately, it looks like the one row we removed was the only bad data point.  We have now successfully coerced our data to numeric form.

# %% [markdown]
# How else could we have done this?  It helped that there was only one bad row of data, but what if there had been lots of rows of bad data?  Repeat the for loop above, but change the errors parameter so that it returns a NaN value for invalid inputs, and then use the dropna command with the inplace parameter to drop the bad rows in place:

# %%
# given the supplied dataset, from yahoo finance, read in the csv file
df = pd.read_csv("AAPL.csv")

# %%
# Your code here:

# %% [markdown]
# As another alternative, if we had known ahead of time that only row 165 was bad, we could have avoided the above.  Pandas will try to be your friend when you read in data.  You can tell it which rows to skip.  You can warn it there will be headers (or not), you can try to coerce dates to datetime objects.  Lots of useful features to explore.

# %%
# given the supplied dataset, from yahoo finance, read in the csv file
df = pd.read_csv("AAPL.csv",skiprows=[166])

# %%
# We're interested in the closing data and corresponding dates.  Let's
# create a new data frame with just the dates and closing prices
closes = df[["Date","Close"]]

# %% [markdown]
# At this point, we have times listed as strings.  We have two options on how to deal with this.  We can segment the strings we're given and turn them into years, months, and days.  Or, we can change the strings into time objects.  This week we'll try the former.

# %%
closes[["Date","Close"]][:10]

# %%
def str_to_ordinal(date_string):
    # we know that our dates are of the form yyyy-mm-dd
    # we'll leverage this to turn these dates in to approximating numbers
    
    data = [int(x) for x in date_string.split("-")]

    ordinal = data[0] + (data[1]-1) / 12 + (data[2]-1) / 31 /12
    
    return ordinal

# %% [markdown]
# With our str_to_ordinal function in hand, we need to convert all of the strings to ordinals.  Use the .applymap( ) method to changes your series of Date strings to a series of Date numbers, and use the .loc( ) method to store this series over the existing strings

# %%
# Your code here:
closes.loc[:,"Date"] =

# %% [markdown]
# Now if we want to know which dates occured within the last year of a particular date, we can do a subtraction and see what is between 0 and 1.
#
# Create a Pandas series which is the difference between our calculated dates, and the string to ordinal conversion of October 10th of 1993.

# %%
# Your code here
timediff =

# %% [markdown]
# Now use the time differences to find every time which was in the year immediately preceding our date.

# %%
# Your code here
mask =

# %% [markdown]
# Now we can take our mask and find the dates which were within one year of our given date.  Use the numpy mean command to find the average of the values in the year preceding our date.  Also use numpy to find the 25th and 75th percentile of the data from the previous year.

# %%
# Your code here:

# %% [markdown]
# Last thing we'll do this week.  We're going to put together all the things we've bene working on.  Create three new columns for our data frame.  One new column for the mean of the data we have in the previous year, the 25th percentile of the data from the preceding year, and the 75th percentile from the preceding year.
#
# To do this, you'll need to write a for loop which iterates over each date you have, creates a mask to extract the closing values for the dates in the year preceding each iterated date, and takes all the means of preceding year data, and turns that into a new column for your data frame.  You should do this as well for the 1st and 3rd quartiles you also calculated above.
#
# I'd suggest creating the data you want to add to the dataframe, and then merging the data in a separate step.  For more on merging, see section notes/recording.

# %%
# %%time

# Your code for taking means and quartiles.

# %%
# Your code for merging your computations with the existing data:

# %%
# what does your final data frame look like?

# %% [markdown]
# ## Problem 5:
# ### Created by: Alan
# ### Undergraduate 2.5 points Graduate 2 points

# %% [markdown]
# ## Let's go to the movies!
#
# Throughout the course of this problem, we're going to use the `pandas` library to explore a film dataset. Don't worry — we won't have to scrape any data — but we will be exploring the `pandas.DataFrame` data structure. The dataset provided contains all of the major movies that were released theatrically between 2005 and 2010 in the United States.
#
# **NOTE:** Executing given cells in this problem more than once _may_ break the problem. If you encounter errors (that are not supposed to be there) please restart your kernel and try again. If this doesn't solve the problem, let us know on Piazza!

# %%
import pandas as pd

# %% [markdown]
# First, let's make sure that we've imported `pandas`. The convention is to **`import pandas as pd`** so as to have an abbreviation for the library name.

# %% [markdown]
# Let's now import our data! It turns out that `pandas` has a really handy method called `read_csv()` which allows us to import any CSV file into a DataFrame. Note that `pandas` automatically assumes that the first row of our CSV is our table headers. However, we have to specify with the `index_col` parameter that the zero-th column is our index — otherwise, it will get read in as an extra column of data and be redundant with the default index created by the DataFrame.

# %%
movies = pd.read_csv('movies.csv', index_col=0)

# %% [markdown]
# We use the `pd.DataFrame.head()` method to look at the first five rows of our DataFrame. (Note that we can use the corresponding `tail()` method to look at the last five rows.

# %%
movies.head()

# %% [markdown]
# Now, let's take a look at the data itself. We have a movie's title, runtime, MPAA rating, date of theatrical release, director, actors, and plot. Let's take a look at individual columns first and see what types of data we're dealing with. When importing data with `pd.read_csv()`, `pandas` usually assumes certain things about the types of your data.

# %%
print('Each column is of type ', type(movies['title']))
print('The title column is of type ', type(movies['title'][0]))
print('The runtime column is of type ', type(movies['runtime'][0]))
print('The theatrical release date column is of type ', type(movies['theatrical_release'][0]))
print('The director column is of type ', type(movies['director'][0]))
print('The actor column is of type ', type(movies['actor'][0]))
print('The plot column is of type ', type(movies['plot'][0]))

# %% [markdown]
# Interesting! It looks like we mostly have columns with strings, except for our runtime column is (as expected) an integer. However, note that `pandas` has no problem importing columns with mixed types if they exist; on top of that, this process is usually slower than importing fixed-type columns. You can force a fixed-type import by specifying the `dtype` parameter to `pd.read_csv()`, which is usually a dictionary of column names and expected data types.
#
# Looking more closely at our column types, we'll see a couple of wrinkles. First, note that the theatrical release column is of type `str` and not `datetime`. Secondly, note that our director and actor columns are a single string despite representing (usually) one or more people. We'll have to deal with these issues later on in searching the data, so let's run a pre-processing step now.
#
# Let's use the `pd.DataFrame.apply()` method, which allows us to efficiently iterate through all of the rows in a column (or the full DataFrame) by applying a function to every row. We can apply a function that we've defined elsewhere, or use a simple one-line `lambda` function. Let's process the theatrical release column as an example, and also use the EXTREMELY useful `pd.to_datetime()` function with `pd.DataFrame.apply()` to cast the entire column to a `pd.Timestamp` type!

# %%
movies['theatrical_release'] = movies['theatrical_release'].apply(lambda date: pd.to_datetime(date))

# %%
print('The theatrical release column is now of type ', type(movies['theatrical_release'][0]))
movies.head()

# %% [markdown]
# Now let's think about the director and actor columns. You might be asking — isn't it bad practice to have potentially multiple individuals contained in a single string? The short answer is yes. It turns out that this data originated from a JSON export from a MongoDB (non-relational or NoSQL) database, where the director and actor columns were actually lists of strings. This nested data-type representation doesn't translate well to the relational row-column format of a `pandas` DataFrame, which is why we have the non-ideal situation where multiple individuals are contained in a single string in a single column. We could blow up the director and actor columns into multiple columns, but then we run into a couple of different problems: what happens to films with differently sized casts? Do we only store the X most important cast members? These are data model design questions that I'll leave as an exercise to the reader.
#
# In the meantime, we're going to check our dataset for `nan`. If you tuned in to this weekend's section, you'll recall that we discussed the concept of `nan`, or **Not a Number**. This pesky data type is technically a `float` but usually represents a missing data point. Rather than break the entire `pd.read_csv()` operation, `pandas` just assumed you meant to have a missing value in that cell and populated it by default with `numpy.nan` instead. (Note that the native Python `math` module has an implementation of `nan` as well.)
#
# Why don't we take a look in our DataFrame and see where (if at all) we have `nan` values? We'll use a Boolean mask to do so. Recall this topic from this weekend's section as well. As a refresher, a Boolean mask is an array of True/False values that correspond to the result of some operation — in this case the `pd.DataFrame.isnull()` method — and we can use it as a mask to restrict our DataFrame to a subset of rows that correspond to only the True values in our Boolean mask.
#
# **IMPORTANT:** In `pandas`, we can construct a Boolean mask on any column using any kind of comparison operator (<, >, ==) and then use the resulting mask as a filter on our original DataFrame to yield a subset of rows that match our restriction. This is a major way of accessing subsets of your data quickly! (Although it is not the only way and perhaps not the fastest depending on what you want to do and what your data looks like.)

# %%
mask = movies.isnull().values
movies[mask]

# %% [markdown]
# Let's just drop these two rows from our DataFrame. (A Google search reveals that these were documentaries - hence the lack of cast.) In some cases, we might want to use something like the `pd.DataFrame.fillna()` method to fill all of our `nan` cells with some default value, but in this one we'll just drop the rows from our DataFrame using `pd.DataFrame.dropna()`. If we were to train an eventual model to predict box office gross, we wouldn't want to necessarily keep these movies for potential selection into our training set, as they're relatively niche documentary films that are likely unrepresentative of the dataset.
#
# _DIGRESSION ON SEMANTICS_: Note that I'm referring to these methods as `pd.DataFrame.dropna()`. That's because they're defined as methods on the DataFrame class in `pandas`. These are not public methods that exist in `pandas` by themselves - they can only be called on an instance of the `pd.DataFrame` class, of which our `movies` variable is one. Contrast this to the `pd.read_csv()` method.
#
# Note that after we drop these two rows, our set of NaN values is non-existent.

# %%
movies = movies.dropna()

# %%
movies[movies.isnull().values]

# %% [markdown]
# Now, for the coding! This part will be relatively hands-off so you're free to interact with the DataFrame however you wish, so long as you use one of the following methods: Boolean masks, `pd.DataFrame.str.contains`, `pd.DataFrame.query`, `pd.DataFrame.iloc`, `pd.DataFrame.loc`, `pd.DataFrame.ix`, `pd.DataFrame.at`, `pd.DataFrame.iat`. I'll leave it an exercise to the reader to brush up on the documentation for said methods. Don't worry if you prefer to stick to one method - just be aware that your DataFrame manipulation toolkit has a number of different approaches! We will go into the various pros/cons and efficiencies of each method at a later point as we dive deeper into `pandas`.
#
# Please write your code below (making sure that it runs!) and also write your answers in a Markdown cell. May the odds be ever in your favour!

# %%
movies

# %% [markdown]
# **1) How many movies did David Fincher direct?**

# %%
# Your code here

# %% [markdown]
# **2) How many movies are rated R?**

# %%
# Your code here

# %% [markdown]
# **3) Which movies did Robert Downey Jr. act in?**

# %%
# Your code here

# %% [markdown]
# **4) What is the plot of the movie _Blades of Glory_ (2007)?**
# Hint: it's located in row 633.

# %%
# Your code here

# %% [markdown]
# **5) What is the latest release date in this dataset? For which movie(s)?**
# Hint 1: You can use `pd.to_datetime('YYYY-MM-DD')` to generate a Timestamp for any date.
# Hint 2: Your answer (or part of it) will correspond to the holiday that the last CSCI E-29 lecture took place on.

# %%
# Your code here

# %% [markdown]
# **6) What is the range of runtimes in our dataset? For which films do they correspond to?**

# %%
# Your code here

# %% [markdown]
# **7) Optional challenge: Who was the most prolific director(s)? The most prolific actor(s)?**
#
# Hint: How efficiently can you solve this problem? Because our director and actor columns are merged strings of individuals, you'll need to use something like `pd.DataFrame.apply` to create new columns that separate the names. You may also want to rely on the `Counter` datatype or something like `itertools.chain.from_iterable` in your code. Each question is doable in one line of code.
#
# Note: If you can't solve this problem, feel free to skip it! No points will be deducted. You might have to do something like this in the real world at some point though...

# %%
# Your code here
